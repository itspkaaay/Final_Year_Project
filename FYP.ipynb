# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
qrred= cv2.imread('qrred.png')
qrblue=cv2.imread('qrblue.png')
qrgreen=cv2.imread('qrgreen.png')

qrred=cv2.cvtColor(qrred,cv2.COLOR_BGR2RGB)
qrblue=cv2.cvtColor(qrblue,cv2.COLOR_BGR2RGB)
qrgreen=cv2.cvtColor(qrgreen,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(qrred)
plt.show()

# %%
plt.imshow(qrgreen)
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, shape=<deprecated parameter>, filternorm=1, filterrad=4.0, imlim=<deprecated parameter>, resample=None, url=None, *, data=None, **kwargs)>

# %%
plt.imshow(qrblue)
plt.show()

# %%
qrred[200,150:250,:0]
# Out:
# array([], shape=(100, 0), dtype=uint8)

# %%
qrred[:,:,1:]=0
qrblue[:,:0:2]=0
qrgreen[:,:,0]=0
qrgreen[:,:,2]=0

# %%
mask=qrred[:,:,0]>0
print(mask)
print(mask.shape)
# Out:
# [[ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]
# (928, 928)

# %%
red_np= np.array(qrred)


qrred[:,:,0]= np.where(mask,255,0)

# %%
plt.imshow(qrred)
plt.show()

# %%
mask=qrblue[:,:,2]>0
print(mask)
print(mask.shape)
blue_np= np.array(qrblue)


qrblue[:,:,2]= np.where(mask,255,0)
plt.imshow(qrblue)
plt.show()
# Out:
# [[ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]
# (928, 928)

# %%
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        ...,
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
# ...

# %%
mask=qrgreen[:,:,1]>0
print(mask)
print(mask.shape)
green_np= np.array(qrgreen)


qrgreen[:,:,1]= np.where(mask,255,0)
plt.imshow(qrgreen)
plt.show()
# Out:
# [[ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]
# (928, 928)

# %%
print(qrgreen)
# Out:
# [[[  0 255   0]
#   [  0 255   0]
#   [  0 255   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]
#
#  [[  0 255   0]
#   [  0 255   0]
#   [  0 255   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]
#
#  [[  0 255   0]
#   [  0 255   0]
#   [  0 255   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]
#
#  ...
#
#  [[  0 255   0]
#   [  0 255   0]
#   [  0 255   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]
#
#  [[  0 255   0]
#   [  0 255   0]
#   [  0 255   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]
#
#  [[  0 255   0]
#   [  0 255   0]
#   [  0 255   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]]

# %%
new_img= qrred+qrgreen+qrblue
plt.imshow(new_img)
plt.show()

# %%
with open()
